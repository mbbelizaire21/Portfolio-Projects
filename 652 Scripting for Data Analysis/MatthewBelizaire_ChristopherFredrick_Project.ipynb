# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
import matplotlib as mp

# %%
df = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#Exploratory Data Analysis 
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
#Descriptive Statistics
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
df['Genre'].describe()
# Out:
# count      16717
# unique        12
# top       Action
# freq        3370
# Name: Genre, dtype: object

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
df['Platform'].describe()
# Out:
# count     16719
# unique       31
# top         PS2
# freq       2161
# Name: Platform, dtype: object

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df['Publisher'].describe()
# Out:
# count               16665
# unique                581
# top       Electronic Arts
# freq                 1356
# Name: Publisher, dtype: object

# %%
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment', 'Square Enix',
#        'Sony Computer Entertainment Europe', 'Virgin Interactive',
#        'LucasArts', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        nan, 'Codemasters', 'Majesco Entertainment', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        'NCSoft', '989 Studios', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
#What genre of video games are most popular globally?

#The most popular Genre is Action, followed by Sports, then Misc. 
plot1 = sns.countplot(x=df["Genre"])
plot1.set_xticklabels(plot1.get_xticklabels(), rotation=60, ha="right")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plot2 = df.plot.scatter(x='Year_of_Release', y='NA_Sales')

'''No correlation between year released and sales number for North America.
This can indicate that while games have gotten more popular over the years, the higher quantity of games
does not autmatically translate to the quality of them which the sales would be a clear indicator of'''
# Out:
# 'No correlation between year released and sales number for North America.\nThis can indicate that while games have gotten more popular over the years, the higher quantity of games\ndoes not autmatically translate to the quality of them which the sales would be a clear indicator of'

# %%
print(df.loc[df["NA_Sales"].idxmax()])

'''Wii Sports, a game from 2006 is a clear outlier in comparison with more recent titles in North America. 
Year of release has little to do with a game's success, but innovation and quality likely do. While the previous
statement likely has some truth to it, most of the original Wii consoles shipped with the console; thus increasing
the sales numbers with each console purchase in most countries'''
# Out:
# Name               Wii Sports
# Platform                  Wii
# Year_of_Release        2006.0
# Genre                  Sports
# Publisher            Nintendo
# NA_Sales                41.36
# EU_Sales                28.96
# JP_Sales                 3.77
# Other_Sales              8.45
# Global_Sales            82.53
# Critic_Score             76.0
# Critic_Count             51.0
# User_Score                  8
# User_Count              322.0
# Developer            Nintendo
# Rating                      E
# Name: 0, dtype: object
# "Wii Sports, a game from 2006 is a clear outlier in comparison with more recent titles in North America. \nYear of release has little to do with a game's success, but innovation and quality likely do. While the previous\nstatement likely has some truth to it, most of the original Wii consoles shipped with the console; thus increasing\nthe sales numbers with each console purchase in most countries"

# %%
#Relatively same trend as before, but games appear to sell more overall throughout time in Japan
plot3 = sns.scatterplot(data = df, x = "Year_of_Release", y = "JP_Sales", hue = "Genre")

plot3.legend(bbox_to_anchor = (1,1), fontsize = 6)
plt.show()

# %%
print(df.loc[df["JP_Sales"].idxmax()])
'''One of the countries where Wii Sports was not sold with the system has a different game (Pokemon) as its top sales'''
# Out:
# Name               Pokemon Red/Pokemon Blue
# Platform                                 GB
# Year_of_Release                      1996.0
# Genre                          Role-Playing
# Publisher                          Nintendo
# NA_Sales                              11.27
# EU_Sales                               8.89
# JP_Sales                              10.22
# Other_Sales                             1.0
# Global_Sales                          31.37
# Critic_Score                            NaN
# Critic_Count                            NaN
# User_Score                              NaN
# User_Count                              NaN
# Developer                               NaN
# Rating                                  NaN
# Name: 4, dtype: object
# 'One of the countries where Wii Sports was not sold with the system has a different game (Pokemon) as its top sales'

# %%
#Global sales over time for all video games
plot4 = sns.scatterplot(data = df, x = "Year_of_Release", y = "Global_Sales", hue = "Genre", style = "Genre")

plot4.legend(bbox_to_anchor = (1,1), fontsize = 6)
plt.show()

#Alternative Plot
sns.lineplot(data = df, x = "Year_of_Release", y = "Global_Sales")
# Out:
# <AxesSubplot:xlabel='Year_of_Release', ylabel='Global_Sales'>

# %%
#More games were sold throughout the 1980s - 1990s than future periods 
print(df.loc[df["Global_Sales"].idxmax()])
# Out:
# Name               Wii Sports
# Platform                  Wii
# Year_of_Release        2006.0
# Genre                  Sports
# Publisher            Nintendo
# NA_Sales                41.36
# EU_Sales                28.96
# JP_Sales                 3.77
# Other_Sales              8.45
# Global_Sales            82.53
# Critic_Score             76.0
# Critic_Count             51.0
# User_Score                  8
# User_Count              322.0
# Developer            Nintendo
# Rating                      E
# Name: 0, dtype: object

# %%
#Negative left-skew indicates most of the values are concentrated on the right side of the histogram
sns.histplot(data = df, x = "Critic_Score", kde = True)

#The mean supports the visualization. It appears that games generally rate above average (50).
print(df[['Critic_Score']].mean())
# Out:
# Critic_Score    68.967679
# dtype: float64

# %%
#What is the top rated game by critics?
df.loc[df["Critic_Score"].idxmax()]
# Out:
# Name                Grand Theft Auto IV
# Platform                           X360
# Year_of_Release                  2008.0
# Genre                            Action
# Publisher          Take-Two Interactive
# NA_Sales                           6.76
# EU_Sales                           3.07
# JP_Sales                           0.14
# Other_Sales                        1.03
# Global_Sales                      11.01
# Critic_Score                       98.0
# Critic_Count                       86.0
# User_Score                          7.9
# User_Count                       2951.0
# Developer                Rockstar North
# Rating                                M
# Name: 51, dtype: object

# %%
#Subsequently, let's check to lowest rated game by critics.  
df.loc[df["Critic_Score"].idxmin()]
# Out:
# Name                         Ride to Hell
# Platform                              PS3
# Year_of_Release                    2013.0
# Genre                              Racing
# Publisher                     Deep Silver
# NA_Sales                             0.02
# EU_Sales                             0.01
# JP_Sales                              0.0
# Other_Sales                          0.01
# Global_Sales                         0.04
# Critic_Score                         13.0
# Critic_Count                          4.0
# User_Score                              1
# User_Count                          218.0
# Developer          Eutechnyx, Deep Silver
# Rating                                  M
# Name: 13690, dtype: object

# %%
df.loc[df['User_Score']=='tbd', 'User_Score']= 0 #Replacing all tbd values with 0
df["User_Score"] = df["User_Score"].astype(float)
df.loc[df["User_Count"].idxmax()]
# Out:
# Name               The Witcher 3: Wild Hunt
# Platform                                 PC
# Year_of_Release                      2015.0
# Genre                          Role-Playing
# Publisher                Namco Bandai Games
# NA_Sales                               0.21
# EU_Sales                               0.46
# JP_Sales                                0.0
# Other_Sales                            0.05
# Global_Sales                           0.72
# Critic_Score                           93.0
# Critic_Count                           32.0
# User_Score                              9.3
# User_Count                          10665.0
# Developer             CD Projekt Red Studio
# Rating                                    M
# Name: 2851, dtype: object

# %%
df.loc[df['User_Score']=='tbd', 'User_Score']= 0 #Replacing all tbd values with 0
df["User_Score"] = df["User_Score"].astype(float) # converting to float
df.dtypes

#Scaling critic score down to equal user score
df['Critic_Score']=df['Critic_Score']/10.0
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53           7.6
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52           8.2
# 3     15.61     10.93      3.28         2.95         32.77           8.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
#Numeric values over time
Met_OvTime = df.groupby(['Year_of_Release'], as_index=False)\
.agg(Critic_Score = ('Critic_Score', 'mean'), User_Score = ('User_Score', 'mean'),
     Global_Sales = ('Global_Sales', 'mean'), NA_Sales = ('NA_Sales', 'mean'),
     EU_Sales = ('EU_Sales', 'mean'), JP_Sales = ('JP_Sales', 'mean'),
     Other_Sales=('Other_Sales', 'mean'), Num_of_Games = ('Name', 'nunique'), Critic_Count = ('Critic_Count', 'mean'),
     User_Count =('User_Count', 'mean'))

Met_OvTime
# Out:
#     Year_of_Release  Critic_Score  User_Score  Global_Sales  NA_Sales  \
# 0            1980.0           NaN         NaN      1.264444  1.176667
# 1            1981.0           NaN         NaN      0.777609  0.726087
# 2            1982.0           NaN         NaN      0.801667  0.747778
# 3            1983.0           NaN         NaN      0.987647  0.456471
# 4            1984.0           NaN         NaN      3.597143  2.377143
# 5            1985.0      5.900000    5.800000      3.852857  2.409286
# 6            1986.0           NaN         NaN      1.765238  0.595238
# 7            1987.0           NaN         NaN      1.358750  0.528750
# 8            1988.0      6.400000    2.200000      3.148000  1.591333
# 9            1989.0           NaN         NaN      4.320588  2.655882
# 10           1990.0           NaN         NaN      3.086875  1.591250
# 11           1991.0           NaN         NaN      0.786098  0.311220
# ...

# %%
df.loc[df['Year_of_Release'] == 2016]
# Out:
#                                  Name Platform  Year_of_Release         Genre  \
# 94                            FIFA 17      PS4           2016.0        Sports
# 108                  Pokemon Sun/Moon      3DS           2016.0  Role-Playing
# 171        Uncharted 4: A Thief's End      PS4           2016.0       Shooter
# 245    Call of Duty: Infinite Warfare      PS4           2016.0       Shooter
# 289                     Battlefield 1      PS4           2016.0       Shooter
# ...                               ...      ...              ...           ...
# 16703           The Longest 5 Minutes      PSV           2016.0        Action
# 16707                Strawberry Nauts      PSV           2016.0     Adventure
# 16714   Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16716         Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16718             Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#Visualization of Critic Score and User_Score over time

import matplotlib.pyplot as plt

x = Met_OvTime['Year_of_Release']
y = Met_OvTime['Critic_Score']
userY = Met_OvTime['User_Score']
plt.plot(x,y, label = 'Critic Score')
plt.legend()
plt.show()

# %%
#User Score over time
plt.plot(x, userY, label= 'User_Score')
plt.legend()
plt.show()

# %%
#Visualization of Critic Score and User_Score over time

plt.plot(x,y, label = 'Critic Score')
plt.plot(x, userY, label= 'User_Score')
plt.legend()
plt.show()

# %%
yg = Met_OvTime['Num_of_Games']
ygScaled = yg/100
plt.plot(x, ygScaled, label = 'Num of Games')
plt.show()

# %%
plt.plot(x,y, label = 'Critic Score')
plt.plot(x, userY, label= 'User_Score')
plt.plot(x, ygScaled, label = 'Num of Games')
plt.legend()
plt.show()

# %%
#Visualization of Sales over time

y2 = Met_OvTime['Global_Sales']
y3 = Met_OvTime['NA_Sales']
y4 = Met_OvTime['EU_Sales']
y5 = Met_OvTime['JP_Sales']
y6 = Met_OvTime['Other_Sales']

plt.plot(x, y2, label = 'Global')
plt.plot(x, y3, label = 'North America')
plt.plot(x, y4, label = 'European Union')
plt.plot(x, y5, label = 'Japan')
plt.plot(x, y6, label = 'Other')
plt.legend()
#plt.xlim('0', '1989')
#plt.ylim('0', '0.5')
plt.show()

#All 3 have similar shapes with peaks in similar years and dips in similar years
#Peaks 1984, 1985, 1988, 1989, 1990

# %%
# Visualization of Counts over time
y7 = Met_OvTime['Critic_Count']
y8 = Met_OvTime['User_Count']
plt.plot(x, y7, label = 'Critic Count')
plt.xlim(2000, 2015)
plt.ylim(0, 40)
plt.legend()
plt.show()

# %%
plt.plot(x, y8, label = 'User Count')
plt.xlim(2000,2015)
plt.ylim(0,800)
plt.legend()
plt.show()

# %%
#String variables by year 
#Key Years 1984, 1985,1986, 1987, 1988, 1989, 1990 
Diff_Platforms = df.groupby(['Year_of_Release', 'Platform'], as_index = False).agg(Count = ('Platform','size'))
eighty4 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1984]
x = eighty4['Platform']
y = eighty4['Count']
#Diff_Platforms['Year_of_Release']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1984 Platforms")
plt.show()

# %%
eighty5 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1985]
x = eighty5['Platform']
y = eighty5['Count']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1985 Platforms")
plt.show()

# %%
eighty6 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1986]
x = eighty6['Platform']
y = eighty6['Count']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1986 Platforms")
plt.show()

# %%
eighty7 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1987]
x = eighty7['Platform']
y = eighty7['Count']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1987 Platforms")
plt.show()

# %%
eighty8 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1988]
x = eighty8['Platform']
y = eighty8['Count']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1988 Platforms")
plt.show()

# %%
eighty9 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1989]
x = eighty9['Platform']
y = eighty9['Count']
#Diff_Platforms['Year_of_Release']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1989 Platforms")
plt.show()

# %%
ninety = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1990]
x = ninety['Platform']
y = ninety['Count']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1990 Platforms")
plt.show()

# %%
ninety1 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1991]
x = ninety1['Platform']
y = ninety1['Count']
#Diff_Platforms['Year_of_Release']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1991 Platforms")
plt.show()

# %%
ninety2 = Diff_Platforms.loc[Diff_Platforms['Year_of_Release'] == 1992]
x = ninety2['Platform']
y = ninety2['Count']
plt.bar(x, y, width=0.4)
plt.xlabel("Platform")
plt.ylabel("Count")
plt.title("1992 Platforms")
plt.show()

# %%
Diff_Genre = df.groupby(['Year_of_Release', 'Genre'], as_index = False).agg(Count = ('Genre','size'))
eighty4 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1984]
x = eighty4['Genre']
y = eighty4['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1984 Genre")
plt.show()
eighty4
# Out:
#     Year_of_Release     Genre  Count
# 26           1984.0    Action      1
# 27           1984.0      Misc      1
# 28           1984.0  Platform      1
# 29           1984.0    Puzzle      3
# 30           1984.0    Racing      3
# 31           1984.0   Shooter      3
# 32           1984.0    Sports      2

# %%
eighty5 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1985]
x = eighty5['Genre']
y = eighty5['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1985 Genre")
plt.show()

# %%
eighty6 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1986]
x = eighty6['Genre']
y = eighty6['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1986 Genre")
plt.show()

# %%
eighty7 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1987]
x = eighty7['Genre']
y = eighty7['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1987 Genre")
plt.show()

# %%
eighty8 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1988]
x = eighty8['Genre']
y = eighty8['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1988 Genre")
plt.show()

# %%
eighty9 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1989]
x = eighty9['Genre']
y = eighty9['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1989 Genre")
plt.show()

# %%
ninety= Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1990]
x = ninety['Genre']
y = ninety['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1990 Genre")
plt.show()

# %%
ninety1 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1991]
x = ninety1['Genre']
y = ninety1['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1991 Genre")

plt.show()

# %%
ninety2 = Diff_Genre.loc[Diff_Genre['Year_of_Release'] == 1992]
x = ninety2['Genre']
y = ninety2['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'red')
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("1992 Genre")
plt.show()


plt.show()

# %%
Diff_Publisher = df.groupby(['Year_of_Release', 'Publisher'], as_index = False).agg(Count = ('Publisher','size'))
eighty4 = Diff_Publisher.loc[Diff_Publisher['Year_of_Release'] == 1984]
x = eighty4['Publisher']
y = eighty4['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'purple')
plt.xlabel("Publisher")
plt.ylabel("Count")
plt.title("1984 Publisher")
plt.show()
eighty4
# Out:
#     Year_of_Release           Publisher  Count
# 38           1984.0          Activision      1
# 39           1984.0         Hudson Soft      1
# 40           1984.0  Namco Bandai Games      3
# 41           1984.0            Nintendo      9

# %%
eighty5 = Diff_Publisher.loc[Diff_Publisher['Year_of_Release'] == 1985]
x = eighty5['Publisher']
y = eighty5['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'purple')
plt.xlabel("Publisher")
plt.ylabel("Count")
plt.title("1985 Publisher")
plt.show()
eighty5
# Out:
#     Year_of_Release           Publisher  Count
# 42           1985.0          Activision      2
# 43           1985.0              Capcom      1
# 44           1985.0         Hudson Soft      1
# 45           1985.0               Mycom      1
# 46           1985.0  Namco Bandai Games      2
# 47           1985.0            Nintendo      7

# %%
eighty6 = Diff_Publisher.loc[Diff_Publisher['Year_of_Release'] == 1986]
x = eighty6['Publisher']
y = eighty6['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'purple')
plt.xlabel("Publisher")
plt.ylabel("Count")
plt.title("1986 Publisher")
plt.show()
eighty6
# Out:
#     Year_of_Release                     Publisher  Count
# 48           1986.0                         Atari      2
# 49           1986.0                        Capcom      3
# 50           1986.0                   Hudson Soft      4
# 51           1986.0  Konami Digital Entertainment      4
# 52           1986.0            Namco Bandai Games      2
# 53           1986.0                      Nintendo      6

# %%
eighty7 = Diff_Publisher.loc[Diff_Publisher['Year_of_Release'] == 1987]
x = eighty7['Publisher']
y = eighty7['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'purple')
plt.xlabel("Publisher")
plt.ylabel("Count")
plt.title("1987 Publisher")
plt.show()
eighty7
# Out:
#     Year_of_Release                     Publisher  Count
# 54           1987.0                    Activision      2
# 55           1987.0                         Atari      4
# 56           1987.0                        Capcom      1
# 57           1987.0              Enix Corporation      1
# 58           1987.0  Konami Digital Entertainment      1
# 59           1987.0            Namco Bandai Games      2
# 60           1987.0                      Nintendo      4
# 61           1987.0                    SquareSoft      1

# %%
eighty8 = Diff_Publisher.loc[Diff_Publisher['Year_of_Release'] == 1988]
x = eighty8['Publisher']
y = eighty8['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'purple')
plt.xlabel("Publisher")
plt.ylabel("Count")
plt.title("1988 Publisher")
plt.show()
eighty8
# Out:
#     Year_of_Release           Publisher  Count
# 62           1988.0          Activision      2
# 63           1988.0              Capcom      2
# 64           1988.0    Enix Corporation      1
# 65           1988.0               Maxis      1
# 66           1988.0  Namco Bandai Games      2
# 67           1988.0            Nintendo      6
# 68           1988.0          SquareSoft      1

# %%
eighty9 = Diff_Publisher.loc[Diff_Publisher['Year_of_Release'] == 1989]
x = eighty9['Publisher']
y = eighty9['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'purple')
plt.xlabel("Publisher")
plt.ylabel("Count")
plt.title("1989 Publisher")
plt.show()
eighty9
# Out:
#     Year_of_Release                     Publisher  Count
# 69           1989.0                    Activision      1
# 70           1989.0                         Atari      1
# 71           1989.0                        Capcom      1
# 72           1989.0                HAL Laboratory      1
# 73           1989.0  Konami Digital Entertainment      1
# 74           1989.0            Namco Bandai Games      1
# 75           1989.0                      Nintendo      9
# 76           1989.0                        Palcom      1
# 77           1989.0                    SquareSoft      1

# %%
ninety = Diff_Publisher.loc[Diff_Publisher['Year_of_Release'] == 1990]
x = ninety['Publisher']
y = ninety['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'purple')
plt.ylabel("Publisher")
plt.xlabel("Count")
plt.title("1990 Publisher")
plt.show()

# %%
xProd =[1984,1985,1986,1987,1988,1989]
yProd = [7.33, 5.6, 2.6, 2.3, 4.5, 8]
plt.plot(xProd, yProd, label = 'Publisher production difference')
plt.legend()
plt.show()

# %%
Diff_Rating = df.groupby(['Year_of_Release', 'Rating'], as_index = False).agg(Count = ('Rating','size'))
eighty4 = Diff_Rating.loc[Diff_Rating['Year_of_Release'] == 1992]
x = eighty4['Rating']
y = eighty4['Count']
fig, ax = plt.subplots(figsize =(16,9))
ax.barh(x, y, color = 'green')
plt.ylabel("Rating")
plt.xlabel("Count")
plt.title("1992 Publisher")
plt.show()

# %%
#Popular Video Game trends
GTA = df[df['Name'].str.contains('Grand Theft Auto', na=False)]
GTA_Met = GTA.groupby(['Name'], as_index=False)\
.agg(Critic_Score = ('Critic_Score', 'mean'), User_Score = ('User_Score', 'mean'),
     Global_Sales = ('Global_Sales', 'mean'), NA_Sales = ('NA_Sales', 'mean'),
     EU_Sales = ('EU_Sales', 'mean'), JP_Sales = ('JP_Sales', 'mean'),
     Other_Sales=('Other_Sales', 'mean'), Num_of_Games = ('Name', 'nunique'), Critic_Count = ('Critic_Count', 'mean'),
     User_Count =('User_Count', 'mean'))
GTA_Scores = GTA_Met.iloc[:,:3]
GTA_Scores


GTA_Scores.plot(x='Name', y =['Critic_Score', 'User_Score'], kind = 'bar')
plt.show()

# %%
GTA_Met
# Out:
#                                                  Name  Critic_Score  \
# 0                                    Grand Theft Auto      6.800000
# 1                                  Grand Theft Auto 2      7.000000
# 2                                Grand Theft Auto III      9.500000
# 3                                 Grand Theft Auto IV      9.533333
# 4                                  Grand Theft Auto V      9.680000
# 5                    Grand Theft Auto: Chinatown Wars      9.150000
# 6              Grand Theft Auto: Liberty City Stories      8.300000
# 7      Grand Theft Auto: Mission Pack #1, London 1969           NaN
# 8                       Grand Theft Auto: San Andreas      9.366667
# 9                         Grand Theft Auto: Vice City      9.450000
# 10                Grand Theft Auto: Vice City Stories      8.050000
# 11  Rockstar Games Double Pack: Grand Theft Auto I...           NaN
#
#     User_Score  Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
GTA_Met.plot(x = 'Name', y = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales'], kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
GTA_Time =GTA.groupby(['Year_of_Release'], as_index=False)\
.agg(Critic_Score = ('Critic_Score', 'mean'), User_Score = ('User_Score', 'mean'),
     Global_Sales = ('Global_Sales', 'mean'), NA_Sales = ('NA_Sales', 'mean'),
     EU_Sales = ('EU_Sales', 'mean'), JP_Sales = ('JP_Sales', 'mean'),
     Other_Sales=('Other_Sales', 'mean'), Num_of_Games = ('Name', 'nunique'), Critic_Count = ('Critic_Count', 'mean'),
     User_Count =('User_Count', 'mean'))

# %%
GTA_Time.plot(x = "Year_of_Release", y = ['Critic_Score','User_Score'], kind = 'line')
# Out:
# <AxesSubplot:xlabel='Year_of_Release'>

# %%
Mario = df[df['Name'].str.contains('Super Mario ', na=False)]
Mario_Met =Mario.groupby(['Name'], as_index=False)\
.agg(Critic_Score = ('Critic_Score', 'mean'), User_Score = ('User_Score', 'mean'),
     Global_Sales = ('Global_Sales', 'mean'), NA_Sales = ('NA_Sales', 'mean'),
     EU_Sales = ('EU_Sales', 'mean'), JP_Sales = ('JP_Sales', 'mean'),
     Other_Sales=('Other_Sales', 'mean'), Num_of_Games = ('Name', 'nunique'), Critic_Count = ('Critic_Count', 'mean'),
     User_Count =('User_Count', 'mean'))

Mario_Met.plot(x='Name', y =['Critic_Score', 'User_Score'], kind = 'bar')
plt.show()

# %%
Mario
# Out:
#                                                 Name Platform  \
# 1                                  Super Mario Bros.      NES
# 6                              New Super Mario Bros.       DS
# 8                          New Super Mario Bros. Wii      Wii
# 18                                 Super Mario World     SNES
# 21                                  Super Mario Land       GB
# 22                               Super Mario Bros. 3      NES
# 45                                    Super Mario 64      N64
# 49                                Super Mario Galaxy      Wii
# 50                Super Mario Land 2: 6 Golden Coins       GB
# 53                               Super Mario 3D Land      3DS
# 56                             Super Mario All-Stars     SNES
# 59                                    Super Mario 64       DS
# 62                           New Super Mario Bros. 2      3DS
# 76                                  Super Mario Kart     SNES
# ...

# %%
Mario_Met.plot(x = 'Name', y = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales'], kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
COD = df[df['Name'].str.contains('Call of Duty', na=False)]
COD_Met = COD.groupby(['Name'], as_index=False)\
.agg(Critic_Score = ('Critic_Score', 'mean'), User_Score = ('User_Score', 'mean'),
     Global_Sales = ('Global_Sales', 'mean'), NA_Sales = ('NA_Sales', 'mean'),
     EU_Sales = ('EU_Sales', 'mean'), JP_Sales = ('JP_Sales', 'mean'),
     Other_Sales=('Other_Sales', 'mean'), Num_of_Games = ('Name', 'nunique'), Critic_Count = ('Critic_Count', 'mean'),
     User_Count =('User_Count', 'mean'))
COD_Met.plot(x='Name', y =['Critic_Score', 'User_Score'], kind = 'bar')
plt.show()

# %%
COD_Met
# Out:
#                                             Name  Critic_Score  User_Score  \
# 0                                 Call of Duty 2      8.750000    8.250000
# 1                                 Call of Duty 3      7.825000    6.875000
# 2                 Call of Duty 4: Modern Warfare      8.875000    8.050000
# 3           Call of Duty Black Ops: Declassified      3.300000    4.800000
# 4                 Call of Duty: Advanced Warfare      8.066667    5.060000
# 5                        Call of Duty: Black Ops      8.200000    5.940000
# 6                      Call of Duty: Black Ops 3           NaN         NaN
# 7                     Call of Duty: Black Ops II      8.025000    5.300000
# 8                      Call of Duty: Finest Hour      7.433333    8.133333
# 9                           Call of Duty: Ghosts      7.380000    3.320000
# 10                Call of Duty: Infinite Warfare      7.600000    3.166667
# ...

# %%
COD_Met.plot(x = 'Name', y = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales'], kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Name'>
